# %%
import imageio
import imageio_ffmpeg
from pathlib import Path

INPUT_DIR = Path(r"C:\Users\Admin\Documents\Python Project\handsign\Smpler_X\input")
OUTPUT_DIR = Path(r"C:\Users\Admin\Documents\Python Project\handsign\Smpler_X\input_mp4")

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()
print("Using ffmpeg backend at:", ffmpeg_path)

for webm in INPUT_DIR.glob("*.webm"):
    mp4 = OUTPUT_DIR / (webm.stem + ".mp4")
    print(f"Converting {webm.name} -> {mp4.name}")

    reader = imageio.get_reader(webm)
    fps = reader.get_meta_data().get("fps", 30)

    writer = imageio.get_writer(
        mp4,
        fps=fps,
        codec="libx264",
        pixelformat="yuv420p"
    )

    for frame in reader:
        writer.append_data(frame)

    reader.close()
    writer.close()

print("✅ Done converting all videos")
# Out:
# Using ffmpeg backend at: c:\Users\Admin\anaconda3\envs\tf\lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe
# Converting D0001B.webm -> D0001B.mp4
# Converting D0001N.webm -> D0001N.mp4
# Converting D0001T.webm -> D0001T.mp4
# Converting D0002.webm -> D0002.mp4
# Converting D0003.webm -> D0003.mp4
# Converting D0004.webm -> D0004.mp4
# Converting D0005B.webm -> D0005B.mp4
# Converting D0005N.webm -> D0005N.mp4
# Converting D0005T.webm -> D0005T.mp4
# Converting D0006.webm -> D0006.mp4
# Converting D0007.webm -> D0007.mp4
# Converting D0008.webm -> D0008.mp4
# Converting D0009.webm -> D0009.mp4
# Converting D0010.webm -> D0010.mp4
# Converting D0011.webm -> D0011.mp4
# Converting D0012.webm -> D0012.mp4
# Converting D0013.webm -> D0013.mp4
# Converting D0014.webm -> D0014.mp4
# Converting D0015.webm -> D0015.mp4
# Converting D0016.webm -> D0016.mp4
# Converting D0017.webm -> D0017.mp4
# Converting D0018.webm -> D0018.mp4
# Converting D0019B.webm -> D0019B.mp4
# ...

# %%
import os
import shutil
import math

# ====== CONFIG ======
source_dir = "input_mp4_full"
num_splits = 40
output_prefix = "input_part_"
# ====================

# Lấy danh sách file mp4
files = [f for f in os.listdir(source_dir) if f.lower().endswith(".mp4")]
files.sort()

total_files = len(files)
files_per_split = math.ceil(total_files / num_splits)

print(f"Total files: {total_files}")
print(f"Files per split: {files_per_split}")

for i in range(num_splits):
    start = i * files_per_split
    end = start + files_per_split
    split_files = files[start:end]

    if not split_files:
        break

    split_folder = f"{output_prefix}{i+1}"
    os.makedirs(split_folder, exist_ok=True)

    for file in split_files:
        src_path = os.path.join(source_dir, file)
        dst_path = os.path.join(split_folder, file)
        shutil.move(src_path, dst_path)   # dùng move (cắt)
        # nếu muốn copy thì dùng shutil.copy2()

    print(f"Created {split_folder} with {len(split_files)} files")

print("Done!")
# Out:
# Total files: 4364
# Files per split: 110
# Created input_part_1 with 110 files
# Created input_part_2 with 110 files
# Created input_part_3 with 110 files
# Created input_part_4 with 110 files
# Created input_part_5 with 110 files
# Created input_part_6 with 110 files
# Created input_part_7 with 110 files
# Created input_part_8 with 110 files
# Created input_part_9 with 110 files
# Created input_part_10 with 110 files
# Created input_part_11 with 110 files
# Created input_part_12 with 110 files
# Created input_part_13 with 110 files
# Created input_part_14 with 110 files
# Created input_part_15 with 110 files
# Created input_part_16 with 110 files
# Created input_part_17 with 110 files
# Created input_part_18 with 110 files
# Created input_part_19 with 110 files
# Created input_part_20 with 110 files
# Created input_part_21 with 110 files
# Created input_part_22 with 110 files
# Created input_part_23 with 110 files
# Created input_part_24 with 110 files
# ...
